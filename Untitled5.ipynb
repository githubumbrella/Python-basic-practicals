# %% [markdown]
# Task 1: Consider Names of two places from the user and find out the distance between them using Geopy library and Mark the location using folium. Now connect both two places on the map by line using Polyline method

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.3.0-py3-none-any.whl (119 kB)
#      ------------------------------------ 119.8/119.8 KB 637.1 kB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      -------------------------------------- 40.3/40.3 KB 970.5 kB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'C:\Users\SRCOEM\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ------------------------------------ 102.3/102.3 KB 590.0 kB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in c:\users\srcoem\anaconda3\lib\site-packages (from folium) (2.10)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\srcoem\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\users\srcoem\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\srcoem\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srcoem\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\srcoem\anaconda3\lib\site-packages (from requests->folium) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\srcoem\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\srcoem\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'C:\Users\SRCOEM\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from geopy.distance import geodesic as GD
from geopy.geocoders import Nominatim

loc1=input("Enter first location :")
geolocator1=Nominatim(user_agent="my_request")
location1=geolocator1.geocode(loc1)

loc2=input("Enter second location :")
geolocator2=Nominatim(user_agent="my_request")
location2=geolocator2.geocode(loc2)

print(location1.address)
print((location1.latitude,location1.longitude))
print(location2.address)
print((location2.latitude,location2.longitude))

la1,lo1=location1.latitude,location1.longitude
la2,lo2=location2.latitude,location2.longitude
# Out:
# Enter first location :paris
# Enter second location :new york
# Paris, Île-de-France, France métropolitaine, France
# (48.8588897, 2.3200410217200766)
# City of New York, New York, United States
# (40.7127281, -74.0060152)

# %%
import folium
world=folium.Map(zoom_start=2)

folium.Marker(location=[la1,lo1,]).add_to(world)
folium.Marker(location=[la2,lo2,]).add_to(world)
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3523c776d1e739c5b9db832fc5dc8ac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3523c776d1e739c5b9db832fc5dc8ac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3523c776d1e739c5b9db832fc5dc8ac8 = L.map(
#                 &quot;map_3523c776d1e739c5b9db832fc5dc8ac8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ea82ae0fa25183f31a87ac01c514cc8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
#
#             var marker_509ed818bc0fa83c009c03079d7ddded = L.marker(
#                 [48.8588897, 2.3200410217200766],
#                 {}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
#
#             var marker_46ee56a759039d25a9a2771962930289 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
place1=(48.8588897, 2.3200410217200766)
place2=(40.7127281, -74.0060152)

print("The distance between two places is : ",GD(place1,place2).km)
# Out:
# The distance between two places is :  5850.655606443813

# %%
p=[(la1,lo1),(la2,lo2)]
folium.PolyLine(p,color='red').add_to(world)
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3523c776d1e739c5b9db832fc5dc8ac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3523c776d1e739c5b9db832fc5dc8ac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3523c776d1e739c5b9db832fc5dc8ac8 = L.map(
#                 &quot;map_3523c776d1e739c5b9db832fc5dc8ac8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ea82ae0fa25183f31a87ac01c514cc8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
#
#             var marker_509ed818bc0fa83c009c03079d7ddded = L.marker(
#                 [48.8588897, 2.3200410217200766],
#                 {}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
#
#             var marker_46ee56a759039d25a9a2771962930289 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
#
#             var poly_line_6d6d9172a5bb15033675ec03d76333f7 = L.polyline(
#                 [[48.8588897, 2.3200410217200766], [40.7127281, -74.0060152]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3523c776d1e739c5b9db832fc5dc8ac8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Task 2. Using “list-indian-states-and-capitals.csv” file get the name of Indian-state-capitals using
# Geopy find the latitude and longitude of the Indian-state-capitals and label the capital on the map
# using folium.

# %%
import pandas as pd
indiamap=pd.read_csv('list-indian-states-and-capitals (1).csv')
print(indiamap.shape)
indiamap
# Out:
# (30, 8)
#                               List of  Indian States          Unnamed: 1  \
# 0                                               S.No         State Name
# 1                                                   1     Andhra Pradesh
# 2                                                   2  Arunachal Pradesh
# 3                                                   3              Assam
# 4                                                   4             Bihar
# 5                                                   5       Chhattisgarh
# 6                                                   6                Goa
# 7                                                   7            Gujarat
# 8                                                   8            Haryana
# 9                                                   9   Himachal Pradesh
# 10                                                 10          Jharkhand
# 11                                                 11          Karnataka
# 12                                                 12             Kerala
# 13                                                 13     Madhya Pradesh
# 14                                                 14        Maharashtra
# 15                                                 15            Manipur
# 16                                                 16          Meghalaya
# 17                                                 17            Mizoram
# 18                                                 18           Nagaland
# 19                                                 19             Odisha
# 20                                                 20             Punjab
# 21                                                 21          Rajasthan
# 22                                                 22             Sikkim
# 23                                                 23         Tamil Nadu
# 24                                                 24         Telangana
# 25                                                 25            Tripura
# 26                                                 26        Uttarakhand
# 27                                                 27     Uttar Pradesh
# 28                                                 28        West Bengal
# 29  For more information, kindly visit : https://w...                NaN
#
#                                            Unnamed: 2       Unnamed: 3  \
# 0                                            Capital             Area
# 1   Hyderabad (de jure)\nAmaravati (de facto)\nVis...   1,60,205 Sq Km
# 2                                            Itanagar    83,743 sq. km
# 3                                              Dispur    78,438 sq. km
# 4                                               Patna    94,163 sq. km
# 5                                         Naya Raipur  1,36,034 sq. km
# 6                                              Panaji     3,702 sq. km
# 7                                         Gandhinagar  1,96,024 sq. km
# 8                                          Chandigarh    44,212 sq. km
# 9              Shimla (Summer)\r\nDharamsala (Winter)    55,673 sq. km
# 10                                             Ranchi    79,714 sq. km
# 11                                          Bangalore  1,91,791 sq. km
# 12                                 Thiruvananthapuram    38,863 sq. km
# 13                                             Bhopal  3,08,000 sq. km
# 14                                            Mumbai   3,07,713 sq. km
# 15                                             Imphal    22,327 sq. km
# 16                                           Shillong    22,429 sq. km
# 17                                             Aizawl    21,081 sq. km
# 18                                             Kohima    16,579 sq. km
# 19                                       Bhubaneshwar  1,55,707 sq. km
# 20                                         Chandigarh    50,362 sq. km
# 21                                             Jaipur  3,42,239 sq. km
# 22                                            Gangtok     7,096 sq. km
# 23                                            Chennai  1,30,058 sq. km
# 24                                          Hyderabad  112,077 Sq. Kms
# 25                                           Agartala    10,491.69 km2
# 26               Gairsain (Summer)\nDehradun (Winter)    53,484 sq. km
# 27                                            Lucknow  2,40,928 sq. km
# 28                                            Kolkata    88,752 sq. km
# 29                                                NaN              NaN
#
#        Unnamed: 4          Unnamed: 5     Unnamed: 6  \
# 0      Population  State Established   Largest City
# 1   49.67 Million          01-10-1953  Visakhapatnam
# 2       13,82,611          20-02-1987       Itanagar
# 3     3,11,69,272          26-01-1950       Guwahati
# 4    10,38,04,637          26-01-1950          Patna
# 5     2,55,40,196          01-11-2000         Raipur
# 6       14,57,723          30-05-1987  Vasco da Gama
# 7     6,03,83,628          01-05-1960      Ahmedabad
# 8     2,53,53,081          01-11-1966      Faridabad
# 9       68,56,509          25-01-1971        Shimla
# 10    3,11,69,272          15-11-2000     Jamshedpur
# 11    6,11,30,704          01-11-1956      Bengaluru
# 12    3,33,87,677          01-11-1956     Malappuram
# 13    7,25,97,565          01-11-1956         Indore
# 14   11,23,72,972          01-05-1960        Mumbai
# 15      27,21,756          21-01-1972       manipur
# 16      29,64,007          21-01-1972       Shillong
# 17      10,91,014          20-02-1987         Aizawl
# 18      19,80,602          01-12-1963        Dimapur
# 19    4,19,47,358          26-01-1950    Bhubaneswar
# 20    2,77,04,236          01-11-1966       Ludhiana
# 21    6,86,21,012          01-11-1956        Jaipur
# 22       6,07,688          16-05-1975        Gangtok
# 23    7,21,38,958          26-01-1950          Tamil
# 24   350.04 Lakhs          02-06-2014      Hyderabad
# 25      36,71,032          21-01-1972       Agartala
# 26    1,01,16,752          26-01-1950       Dehradun
# 27   19,95,81,477          09-11-2000        Lucknow
# 28    9,13,47,736          26-01-1950        Kolkata
# 29            NaN                 NaN            NaN
#
#                                            Unnamed: 7
# 0                                           Languages
# 1                                             Telugu
# 2   Monpa, Miji, Aka, Sherdukpen, \nNyishi, Apatan...
# 3                                            Assamese
# 4                                         Hindi ,Urdu
# 5                                               Hindi
# 6   Konkani(official Language),\nMarathi, Hindi, E...
# 7                                            Gujarati
# 8                                               Hindi
# 9                                      Hindi & Pahari
# 10                                              Hindi
# 11                                            Kannada
# 12                                          Malayalam
# 13                                              Hindi
# 14                                            Marathi
# 15                                           Manipuri
# 16                            Khasi, Garo and English
# 17                                   Mizo and English
# 18              English, Hindi and 16 tribal dialects
# 19                                              Oriya
# 20                                            Punjabi
# 21                               Hindi and Rajasthani
# 22                          Lepcha, Bhutia and Nepali
# 23                                            Chennai
# 24                                       Telugu, Urdu
# 25                               Bengali and Kokborok
# 26                           Hindi, Garhwali, Kumaoni
# 27                                     Hindi and Urdu
# 28                                            Bengali
# 29                                                NaN
