# %%
## Name: Purva Gholse
## roll no.: 12
## batch: C1

# %% [markdown]
# 1.Write a program that reads a file and performs the following tasks:
#
# 2.Count and display the term frequencies of all the words [exclude stop words like- the, a, and] and find the keyword for the document & write the output in a separate file.
#
# 3.Now read the file created in a). .Your program should convert all the input to lowercase  & display the updated count.

# %%
#a
import keyword 
keys = keyword.kwlist 

f1=open("sample1.txt","r")
content=f1.read()
content2=content.split(' ')

stopword=["the","a","and"]
newtext=[x for x in content2 if x not in stopword]
' '.join(newtext)
d=dict()
for i in newtext:
  words=i.split(" ")
  for word in words:
    if word in d:
      d[word]=d[word]+1
    else:
      d[word]=1
for key in list(d.keys()):
  print(key,":", d[key])


for i in range (len(newtext)):
  if keyword.iskeyword(newtext[i]):
    print(newtext[i] + " is a keyword")


f2=open("/content/new","w")
f2.write(str(d))
# Out:
# Harnoor : 1
# Singh : 1
# struck : 1
# fine : 1
# hundred : 1
# before : 1
# Indian : 2
# bowlers : 1
# ran : 1
# through : 1
# opposition : 1
# to : 3
# complete : 1
# 154-run : 1
# rout : 1
# of : 2
# UAE : 1
# in : 4
# their : 2
# opening : 1
# U19 : 1
# Asia : 1
# Cup : 2
# match : 1
# on : 4
# Thursday. : 1
# Put : 1
# bat, : 1
# India : 2
# put : 1
# up : 2
# 282 : 1
# for : 3
# five, : 1
# courtesy : 1
# Harnoor's : 1
# 120 : 1
# off : 3
# 130 : 1
# balls : 2
# skipper : 1
# Yash : 1
# Dhull's : 1
# 63 : 1
# 68 : 1
# balls. : 1
# Rajvardhan : 1
# Hangargekar's : 1
# unbeaten : 1
# 48 : 1
# 23 : 1
# provided : 1
# final : 1
# flourish.
#  : 1
#
# UAE : 1
# used : 1
# as : 2
# many : 1
# nine : 1
# bowling : 2
# options : 1
# at : 1
# ICC : 1
# Academy : 1
# Ground : 1
# but : 1
# move : 1
# did : 1
# not : 1
# help : 1
# cause.
#  : 1
#
# The : 1
# home : 1
# team's : 1
# batters : 1
# came : 1
# cropper : 1
# against : 1
# line : 1
# up, : 1
# folding : 1
# 128 : 1
# 34.3 : 1
# overs.
#  : 1
#
# Hangargekar : 1
# took : 2
# three : 1
# wickets : 2
# while : 1
# Garv : 1
# Sangwan, : 1
# Vicky : 1
# Oswal : 1
# Kaushal : 1
# Tamble : 1
# two : 1
# each.
#  : 1
#
# India : 1
# next : 2
# play : 1
# arch-rivals : 1
# Pakistan : 2
# Saturday.
#  : 1
#
# In : 1
# other : 1
# matches : 1
# played : 2
# Thursday, : 1
# beat : 1
# Afghanistan : 1
# by : 2
# four : 1
# Sri : 1
# Lanka : 1
# hammered : 1
# Kuwait : 1
# 274 : 1
# runs.
#  : 1
#
# Listen : 1
# latest : 1
# songs, : 1
# only : 1
# JioSaavn.com
# The : 1
# tournament : 1
# is : 1
# being : 1
# ahead : 1
# U-19 : 1
# World : 1
# West : 1
# Indies : 1
# month.
#  : 1
# in is a keyword
# in is a keyword
# for is a keyword
# as is a keyword
# as is a keyword
# not is a keyword
# for is a keyword
# in is a keyword
# for is a keyword
# while is a keyword
# is is a keyword
# in is a keyword
# 1647

# %%
#b
for i in newtext:
  
  i=i.lower()
  words=i.split(" ")

  

  for word in words:
    

    if word in d:
      d[word]=d[word]+1


    else:
      d[word]=1

for key in list(d.keys()):
  print(key,":", d[key])
# Out:
# Harnoor : 1
# Singh : 1
# struck : 2
# fine : 2
# hundred : 2
# before : 2
# Indian : 2
# bowlers : 2
# ran : 2
# through : 2
# opposition : 2
# to : 6
# complete : 2
# 154-run : 2
# rout : 2
# of : 4
# UAE : 1
# in : 8
# their : 4
# opening : 2
# U19 : 1
# Asia : 1
# Cup : 2
# match : 2
# on : 8
# Thursday. : 1
# Put : 1
# bat, : 2
# India : 2
# put : 3
# up : 4
# 282 : 2
# for : 6
# five, : 2
# courtesy : 2
# Harnoor's : 1
# 120 : 2
# off : 6
# 130 : 2
# balls : 4
# skipper : 2
# Yash : 1
# Dhull's : 1
# 63 : 2
# 68 : 2
# balls. : 2
# Rajvardhan : 1
# Hangargekar's : 1
# unbeaten : 2
# 48 : 2
# 23 : 2
# provided : 2
# final : 2
# flourish.
#  : 2
#
# UAE : 1
# used : 2
# as : 4
# many : 2
# nine : 2
# bowling : 4
# options : 2
# at : 2
# ICC : 1
# Academy : 1
# Ground : 1
# but : 2
# move : 2
# did : 2
# not : 2
# help : 2
# cause.
#  : 2
#
# The : 1
# home : 2
# team's : 2
# batters : 2
# came : 2
# cropper : 2
# against : 2
# line : 2
# up, : 2
# folding : 2
# 128 : 2
# 34.3 : 2
# overs.
#  : 2
#
# Hangargekar : 1
# took : 4
# three : 2
# wickets : 4
# while : 2
# Garv : 1
# Sangwan, : 1
# Vicky : 1
# Oswal : 1
# Kaushal : 1
# Tamble : 1
# two : 2
# each.
#  : 2
#
# India : 1
# next : 4
# play : 2
# arch-rivals : 2
# Pakistan : 2
# Saturday.
#  : 1
#
# In : 1
# other : 2
# matches : 2
# played : 4
# Thursday, : 1
# beat : 2
# Afghanistan : 1
# by : 4
# four : 2
# Sri : 1
# Lanka : 1
# hammered : 2
# Kuwait : 1
# 274 : 2
# runs.
#  : 2
#
# Listen : 1
# latest : 2
# songs, : 2
# only : 2
# JioSaavn.com
# The : 1
# tournament : 2
# is : 2
# being : 2
# ahead : 2
# U-19 : 1
# World : 1
# West : 1
# Indies : 1
# month.
#  : 2
# harnoor : 1
# singh : 1
# indian : 2
# uae : 1
# u19 : 1
# asia : 1
# cup : 2
# thursday. : 1
# india : 2
# harnoor's : 1
# yash : 1
# dhull's : 1
# rajvardhan : 1
# hangargekar's : 1
#
# uae : 1
# icc : 1
# academy : 1
# ground : 1
#
# the : 1
#
# hangargekar : 1
# garv : 1
# sangwan, : 1
# vicky : 1
# oswal : 1
# kaushal : 1
# tamble : 1
#
# india : 1
# pakistan : 2
# saturday.
#  : 1
#
# in : 1
# thursday, : 1
# afghanistan : 1
# sri : 1
# lanka : 1
# kuwait : 1
#
# listen : 1
# jiosaavn.com
# the : 1
# u-19 : 1
# world : 1
# west : 1
# indies : 1

# %% [markdown]
# Write a program to read through the mailbox data and when you find a line that starts with “From”, you will split the line into words using the split function. We are interested in who sent the message, which is the second word on the From line.
# Example: From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008
# [Note: first create such file]
# You will parse the From line and print out the second word for each From line, then you will also count the number of From lines and print out a count at the end.

# %%
with open("que.txt",'r') as data_file:
  
    for line in data_file:
        data = line.split()[1]
        print("the required address is: ")
        print(data)
# Out:
# the required address is:
# stephen.marquard@uct.ac.za
# the required address is:
# purva.gholse@gmail.com
# the required address is:
# abcd@gmail.com
# the required address is:
# pqrs@gmail.com
# the required address is:
# wxyz@gmail.com

# %%
with open("que.txt",'r') as data_file:
  count=len(data_file.readlines())
  print("the count will be: ",count)
# Out:
# the count will be:  5

# %% [markdown]
# Write a program using functions and file. The create_file function writes information to the file “food.txt”. The contents_of_file function takes the names of the food items as arguments and returns the information of the food item in a nicely formatted block. The file should have contents like- Name of the item, ingrediants, recepie, star, etc.  Further read the file and find all the items, create a list of itemname and display.

# %%
f=open("food.txt","w")
with open("food.txt","w") as f: 
  n=int(input("enter the number of items: "))
  for x in range (n): 
    a=str(input("name of the item: "))
    b=str(input("ingredients: "))
    c=str(input("recepie: "))
    d=str(input("star: "))
    new_line="\n"
    f.write("item name")
    f.write(new_line)
    f.write(a)
    f.write(new_line)
    f.write("ingredients ")
    f.write(new_line)
    f.write(b)
    f.write(new_line)
    f.write("recipie")
    f.write(new_line)
    f.write(c)
    f.write(new_line)
    f.write("star")
    f.write(new_line)
    f.write(d)    
f.close()
# Out:
# enter the number of items: 3
# name of the item: sandwich
# ingredients: bread butter tomato cucumber sauce
# recepie: put the tomato and cucumber over bread slices with sauce and heat it on the pan with butter
# star: bread
# name of the item: boiled egg
# ingredients: egg water
# recepie: put egg into water and boil it for fifteen minutes
# star: egg
# name of the item: rice
# ingredients: rice water salt
# recepie: wash rice properly and add salt into it then heat it in a cooker for twenty minutes on low flame
# star: rice

# %%
p=open("food.txt","r")
print(p.read())
# Out:
# item name
# sandwich
# ingredients
# bread butter tomato cucumber sauce
# recipie
# put the tomato and cucumber over bread slices with sauce and heat it on the pan with butter
# star
# breaditem name
# boiled egg
# ingredients
# egg water
# recipie
# put egg into water and boil it for fifteen minutes
# star
# eggitem name
# rice
# ingredients
# rice water salt
# recipie
# wash rice properly and add salt into it then heat it in a cooker for twenty minutes on low flame
# star
# rice
